# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
true=pd.read_csv("/content/True.csv")
fake=pd.read_csv("/content/Fake.csv")

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['class']=0
true['class']=1

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  class
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
data = pd.concat([fake,true],axis=0)

# %%
data.sample(5)
# Out:
#                                                    title  \
# 12592  CAMPAIGN VOLUNTEERS Deliver Opposing Messages:...
# 11250  House of Representatives to try again to seek ...
# 4527   Democrat Donnelly to support Trump pick for U....
# 9002   Latest gun control bid falters in Congress, De...
# 18947  Russia warns Iraq, Kurds not to destabilize Mi...
#
#                                                     text       subject  \
# 12592  ILLEGAL ALIENS WHO CAN T Vote Are Knocking On ...      politics
# 11250  WASHINGTON (Reuters) - The U.S. House of Repre...  politicsNews
# 4527   WASHINGTON (Reuters) - Democratic U.S. Senator...  politicsNews
# 9002   WASHINGTON (Reuters) - Another attempt at gun ...  politicsNews
# 18947  MOSCOW (Reuters) - Russia on Wednesday warned ...     worldnews
#
#                       date  class
# 12592         Oct 28, 2016      0
# 11250    January 13, 2016       1
# 4527        April 2, 2017       1
# 9002        June 23, 2016       1
# 18947  September 27, 2017       1

# %%
data = data.drop(["subject","date","title"],axis=1)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 1441   The Trump administration is in a tailspin afte...      0
# 14259  LONDON (Reuters) - Northern Ireland s main pol...      1
# 20496  PHNOM PENH (Reuters) - Cambodia s main opposit...      1
# 4839   This is so horribly amazing that it defies des...      0
# 22284  21st Century Wire says In the wake of the Frid...      0

# %%
data.reset_index(inplace = True)

# %%
data.sample(5)
# Out:
#        index                                               text  class
# 15700  15700                                                         0
# 2145    2145  FBI Director James Comey could very likely be ...      0
# 35626  12145  UNITED NATIONS/YANGON (Reuters) - U.S. Secreta...      1
# 28917   5436  (Reuters) - President Donald Trump acted well ...      1
# 22659  22659   21st Century Wire asks HAVE YOUR SHOUT: With ...      0

# %%
data.drop(['index'],axis=1,inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 26383  MEXICO CITY (Reuters) - A meeting between Mexi...      1
# 15182  On Monday s broadcast of the syndicated show  ...      0
# 15587  Why do we even need a Congress anymore? We hav...      0
# 7798   Over the course of this latest presidential ca...      0
# 33741  WASHINGTON (Reuters) - As the Senate began a t...      1

# %%
import re
import string

def clean_text(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    return text

# %%
data["text"] = data["text"].apply(clean_text)

# %%
x = data["text"]
y = data["class"]

xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, test_size=0.25, random_state=42
)

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(xtrain)
xv_test  = vectorizer.transform(xtest)

# %%
lr = LogisticRegression()
lr.fit(xv_train,ytrain)
# Out:
# LogisticRegression()

# %%
prediction = lr.predict(xv_test)
lr.score(xv_test,ytest)
# Out:
# 0.9858351893095768

# %%
print(classification_report(ytest,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']
